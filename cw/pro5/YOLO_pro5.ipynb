# %% [markdown]
# https://docs.ultralytics.com/yolov5/tutorials/train_custom_data/

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16656, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 16656 (delta 1), reused 5 (delta 0), pack-reused 16649
# Receiving objects: 100% (16656/16656), 15.07 MiB | 7.50 MiB/s, done.
# Resolving deltas: 100% (11443/11443), done.

# %%
# %pip install -r /content/yolov5/requirements.txt
# %pip install comet_ml roboflow

# %% [markdown]
# # zad 1
# Przygotuj zbiór danych z minimum 4 kategoriami. Z każdej kategori ma być minimum 20 przykładów. Z zaznaczeniem że jeśli zdjęcia są z jednego filmu lub jednej sytuacji, czyli mają podobne oświetlenie, to przykłądów powinno być minimum 2 razy więcej.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="4ErPU6YvzJeigAM2hynU")
project = rf.workspace("testset-7hshq").project("wma-u0rqo")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Wma-4 in yolov5pytorch:: 100%|██████████| 108/108 [00:00<00:00, 7017.25it/s]
# mv: cannot stat 'Wma-3': No such file or directory

# %%
# !mv Wma-4 yolov5/
# !mkdir yolov5/Wma-4/data
# !mv yolov5/Wma-4/data.yaml yolov5/Wma-4/data/

# %% [markdown]
# # zad 2
# Wybierz odpowiedni dla siebie model i wytrenuj na losowych wagach oraz na juz wytrenowanych.

# %%
# !python "/content/yolov5/train.py" --img 640 --epochs 300 --data "/content/yolov5/Wma-4/data/data.yaml" --weights yolov5s.pt
# Out:
# 2024-06-05 06:37:13.171782: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 06:37:13.171835: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 06:37:13.173207: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python "/content/yolov5/train.py" --img 640 --epochs 300 --data "/content/yolov5/Wma-4/data/data.yaml" --weights '' --cfg /content/yolov5/models/yolov5s.yaml
# Out:
# 2024-06-05 06:57:06.405646: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-05 06:57:06.405704: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-05 06:57:06.407106: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # zad 3
# Wykonaj detekcję obydwu modeli na przykładowym filmie i porównaj rezultaty.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp /content/drive/myDrive/PJATK/WMA/pro5/IMG_2590.MOV /content/IMG_2590.MOV

drive.flush_and_unmount()

# %%
# !python /content/yolov5/detect.py --source /content/IMG_2590.MOV --weights /content/yolov5/runs/train/exp2/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/IMG_2590.MOV, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/361) /content/IMG_2590.MOV: 640x384 1 eye, 1 mouth, 50.7ms
# video 1/1 (2/361) /content/IMG_2590.MOV: 640x384 1 eye, 1 mouth, 9.9ms
# video 1/1 (3/361) /content/IMG_2590.MOV: 640x384 1 eye, 1 mouth, 11.0ms
# ...
